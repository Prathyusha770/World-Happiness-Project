# %% [markdown]
# <a href="https://colab.research.google.com/github/Prathyusha770/World-Happiness-Project/blob/main/World_Happiness_Report_Analysis_EDA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Importing Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Collecting the DataSet

# %%
df = pd.read_csv("WHR2024.csv")

# %% [markdown]
# Understanding the DataSet

# %%
df
# Out:
#          Country name  Ladder score  upperwhisker  lowerwhisker  \
# 0             Finland         7.741         7.815         7.667
# 1             Denmark         7.583         7.665         7.500
# 2             Iceland         7.525         7.618         7.433
# 3              Sweden         7.344         7.422         7.267
# 4              Israel         7.341         7.405         7.277
# ..                ...           ...           ...           ...
# 138  Congo (Kinshasa)         3.295         3.462         3.128
# 139      Sierra Leone         3.245         3.366         3.124
# 140           Lesotho         3.186         3.469         2.904
# 141           Lebanon         2.707         2.797         2.616
# 142       Afghanistan         1.721         1.775         1.667
#
#      Explained by: Log GDP per capita  Explained by: Social support  \
# 0                               1.844                         1.572
# ...

# %%
df.shape
# Out:
# (143, 11)

# %%
df.describe()
# Out:
#        Ladder score  upperwhisker  lowerwhisker  \
# count    143.000000    143.000000    143.000000
# mean       5.527580      5.641175      5.413972
# std        1.170717      1.155008      1.187133
# min        1.721000      1.775000      1.667000
# 25%        4.726000      4.845500      4.606000
# 50%        5.785000      5.895000      5.674000
# 75%        6.416000      6.507500      6.319000
# max        7.741000      7.815000      7.667000
#
#        Explained by: Log GDP per capita  Explained by: Social support  \
# count                        140.000000                    140.000000
# mean                           1.378807                      1.134329
# std                            0.425098                      0.333317
# min                            0.000000                      0.000000
# 25%                            1.077750                      0.921750
# 50%                            1.431500                      1.237500
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 143 entries, 0 to 142
# Data columns (total 11 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   Country name                                143 non-null    object
#  1   Ladder score                                143 non-null    float64
#  2   upperwhisker                                143 non-null    float64
#  3   lowerwhisker                                143 non-null    float64
#  4   Explained by: Log GDP per capita            140 non-null    float64
#  5   Explained by: Social support                140 non-null    float64
#  6   Explained by: Healthy life expectancy       140 non-null    float64
#  7   Explained by: Freedom to make life choices  140 non-null    float64
#  8   Explained by: Generosity                    140 non-null    float64
# ...

# %%
df.columns
# Out:
# Index(['Country name', 'Ladder score', 'upperwhisker', 'lowerwhisker',
#        'Explained by: Log GDP per capita', 'Explained by: Social support',
#        'Explained by: Healthy life expectancy',
#        'Explained by: Freedom to make life choices',
#        'Explained by: Generosity', 'Explained by: Perceptions of corruption',
#        'Dystopia + residual'],
#       dtype='object')

# %%
df.nunique()
# Out:
# Country name                                  143
# Ladder score                                  140
# upperwhisker                                  140
# lowerwhisker                                  136
# Explained by: Log GDP per capita              134
# Explained by: Social support                  124
# Explained by: Healthy life expectancy         119
# Explained by: Freedom to make life choices    122
# Explained by: Generosity                      110
# Explained by: Perceptions of corruption       112
# Dystopia + residual                           134
# dtype: int64

# %%
df.dtypes
# Out:
# Country name                                   object
# Ladder score                                  float64
# upperwhisker                                  float64
# lowerwhisker                                  float64
# Explained by: Log GDP per capita              float64
# Explained by: Social support                  float64
# Explained by: Healthy life expectancy         float64
# Explained by: Freedom to make life choices    float64
# Explained by: Generosity                      float64
# Explained by: Perceptions of corruption       float64
# Dystopia + residual                           float64
# dtype: object

# %% [markdown]
# Finding null values

# %%
df.isnull().sum()
# Out:
# Country name                                  0
# Ladder score                                  0
# upperwhisker                                  0
# lowerwhisker                                  0
# Explained by: Log GDP per capita              3
# Explained by: Social support                  3
# Explained by: Healthy life expectancy         3
# Explained by: Freedom to make life choices    3
# Explained by: Generosity                      3
# Explained by: Perceptions of corruption       3
# Dystopia + residual                           3
# dtype: int64

# %% [markdown]
# Filling null values

# %%
df1=df.copy()

# %%
df1.fillna('0')
# Out:
#          Country name  Ladder score  upperwhisker  lowerwhisker  \
# 0             Finland         7.741         7.815         7.667
# 1             Denmark         7.583         7.665         7.500
# 2             Iceland         7.525         7.618         7.433
# 3              Sweden         7.344         7.422         7.267
# 4              Israel         7.341         7.405         7.277
# ..                ...           ...           ...           ...
# 138  Congo (Kinshasa)         3.295         3.462         3.128
# 139      Sierra Leone         3.245         3.366         3.124
# 140           Lesotho         3.186         3.469         2.904
# 141           Lebanon         2.707         2.797         2.616
# 142       Afghanistan         1.721         1.775         1.667
#
#     Explained by: Log GDP per capita Explained by: Social support  \
# 0                              1.844                        1.572
# ...

# %% [markdown]
# Renaming the features for better understanding

# %%
df1 = df1.rename(columns={'Explained by: Log GDP per capita': 'Log GDP per capita', 'Explained by: Social support': 'Social support',
                          'Explained by: Healthy life expectancy':'Healthy life expectancy','Explained by: Freedom to make life choices':'Freedom to make life choices',
                          'Explained by: Generosity':'Generosity','Explained by: Perceptions of corruption':'Perceptions of corruption','Dystopia + residual':'Dystopia Residual'})

# %%
df1
# Out:
#          Country name  Ladder score  upperwhisker  lowerwhisker  \
# 0             Finland         7.741         7.815         7.667
# 1             Denmark         7.583         7.665         7.500
# 2             Iceland         7.525         7.618         7.433
# 3              Sweden         7.344         7.422         7.267
# 4              Israel         7.341         7.405         7.277
# ..                ...           ...           ...           ...
# 138  Congo (Kinshasa)         3.295         3.462         3.128
# 139      Sierra Leone         3.245         3.366         3.124
# 140           Lesotho         3.186         3.469         2.904
# 141           Lebanon         2.707         2.797         2.616
# 142       Afghanistan         1.721         1.775         1.667
#
#      Log GDP per capita  Social support  Healthy life expectancy  \
# 0                 1.844           1.572                    0.695
# ...

# %%
df1["Happiness_score"] = (df1["Log GDP per capita"] + df1["Social support"] + df1["Healthy life expectancy"] + df1["Freedom to make life choices"]
                          + df1["Generosity"] + df1["Perceptions of corruption"] + df1["Dystopia Residual"])

# %%
df1
# Out:
#          Country name  Ladder score  upperwhisker  lowerwhisker  \
# 0             Finland         7.741         7.815         7.667
# 1             Denmark         7.583         7.665         7.500
# 2             Iceland         7.525         7.618         7.433
# 3              Sweden         7.344         7.422         7.267
# 4              Israel         7.341         7.405         7.277
# ..                ...           ...           ...           ...
# 138  Congo (Kinshasa)         3.295         3.462         3.128
# 139      Sierra Leone         3.245         3.366         3.124
# 140           Lesotho         3.186         3.469         2.904
# 141           Lebanon         2.707         2.797         2.616
# 142       Afghanistan         1.721         1.775         1.667
#
#      Log GDP per capita  Social support  Healthy life expectancy  \
# 0                 1.844           1.572                    0.695
# ...

# %% [markdown]
# # Distribution of Happiness Score

# %%
df1.fillna('0.00')
# Out:
#          Country name  Ladder score  upperwhisker  lowerwhisker  \
# 0             Finland         7.741         7.815         7.667
# 1             Denmark         7.583         7.665         7.500
# 2             Iceland         7.525         7.618         7.433
# 3              Sweden         7.344         7.422         7.267
# 4              Israel         7.341         7.405         7.277
# ..                ...           ...           ...           ...
# 138  Congo (Kinshasa)         3.295         3.462         3.128
# 139      Sierra Leone         3.245         3.366         3.124
# 140           Lesotho         3.186         3.469         2.904
# 141           Lebanon         2.707         2.797         2.616
# 142       Afghanistan         1.721         1.775         1.667
#
#     Log GDP per capita Social support Healthy life expectancy  \
# 0                1.844          1.572                   0.695
# 1                1.908           1.52                   0.699
# ...

# %%
df1.isnull().sum()
# Out:
# Country name                    0
# Ladder score                    0
# upperwhisker                    0
# lowerwhisker                    0
# Log GDP per capita              3
# Social support                  3
# Healthy life expectancy         3
# Freedom to make life choices    3
# Generosity                      3
# Perceptions of corruption       3
# Dystopia Residual               3
# Happiness_score                 3
# dtype: int64

# %%
df.iloc[100:105]
# Out:
#            Country name  Ladder score  upperwhisker  lowerwhisker  \
# 100          Azerbaijan         4.893         5.018         4.768
# 101             Nigeria         4.881         5.018         4.744
# 102  State of Palestine         4.879         5.006         4.753
# 103            Cameroon         4.874         4.996         4.753
# 104             Ukraine         4.873         4.988         4.758
#
#      Explained by: Log GDP per capita  Explained by: Social support  \
# 100                             1.433                         0.876
# 101                             1.042                         1.075
# 102                               NaN                           NaN
# 103                             0.943                         0.856
# 104                             1.350                         1.315
#
#      Explained by: Healthy life expectancy  \
# 100                                  0.496
# 101                                  0.256
# ...

# %%
df.fillna(0, inplace=True)

# %%
df.isnull().sum()
# Out:
# Country name                                  0
# Ladder score                                  0
# upperwhisker                                  0
# lowerwhisker                                  0
# Explained by: Log GDP per capita              0
# Explained by: Social support                  0
# Explained by: Healthy life expectancy         0
# Explained by: Freedom to make life choices    0
# Explained by: Generosity                      0
# Explained by: Perceptions of corruption       0
# Dystopia + residual                           0
# dtype: int64

# %%
df1.loc[63, 'Happiness_score']
# Out:
# np.float64(5.934)

# %%
total_score = df1['Happiness_score'].sum()

# %%
print(total_score)
# Out:
# 774.3330000000001

# %% [markdown]
# Finding Outliers by IQR

# %%
sns.boxplot(x="Happiness_score",data=df1)
# Out:
# <Axes: xlabel='Happiness_score'>

# %%
Q1 = df1['Happiness_score'].quantile(0.25)
print(Q1)
# Out:
# 4.632

# %%
Q3 = df1['Happiness_score'].quantile(0.75)
print(Q3)
# Out:
# 6.426

# %%
IQR = Q3-Q1
print(IQR)
# Out:
# 1.7940000000000005

# %%
lower_bound = Q1 - 1.5 * IQR
print(lower_bound)

upper_bound = Q3 + 1.5 * IQR
print(upper_bound)
# Out:
# 1.940999999999999
# 9.117

# %%
# Finding the Outliers (Masking)
outliers = df1[(df1['Happiness_score'] < lower_bound) | (df1['Happiness_score'] > upper_bound)]
outliers
# Out:
#     Country name  Ladder score  upperwhisker  lowerwhisker  \
# 142  Afghanistan         1.721         1.775         1.667
#
#      Log GDP per capita  Social support  Healthy life expectancy  \
# 142               0.628             0.0                    0.242
#
#      Freedom to make life choices  Generosity  Perceptions of corruption  \
# 142                           0.0       0.091                      0.088
#
#      Dystopia Residual  Happiness_score
# 142              0.672            1.721

# %%
from IPython.display import display
display(outliers)
# Out:
#     Country name  Ladder score  upperwhisker  lowerwhisker  \
# 142  Afghanistan         1.721         1.775         1.667
#
#      Log GDP per capita  Social support  Healthy life expectancy  \
# 142               0.628             0.0                    0.242
#
#      Freedom to make life choices  Generosity  Perceptions of corruption  \
# 142                           0.0       0.091                      0.088
#
#      Dystopia Residual  Happiness_score
# 142              0.672            1.721

# %%
df2=df.copy()

# %%
df2 = df1[(df1['Happiness_score'] >= lower_bound) & (df1['Happiness_score'] <= upper_bound)]

# %%
df2.columns
# Out:
# Index(['Country name', 'Ladder score', 'upperwhisker', 'lowerwhisker',
#        'Log GDP per capita', 'Social support', 'Healthy life expectancy',
#        'Freedom to make life choices', 'Generosity',
#        'Perceptions of corruption', 'Dystopia Residual', 'Happiness_score'],
#       dtype='object')

# %% [markdown]
# Removing outliers

# %%
sns.boxplot( x ="Happiness_score",data=df2)
# Out:
# <Axes: xlabel='Happiness_score'>

# %% [markdown]
# Covariance and correlation of healthy life expectancy and happiness score

# %%
df2[['Healthy life expectancy', 'Happiness_score']].cov()
# Out:
#                          Healthy life expectancy  Happiness_score
# Healthy life expectancy                 0.026829         0.141296
# Happiness_score                         0.141296         1.299414

# %%
corr=df2[['Healthy life expectancy', 'Happiness_score']].corr()

# %%
corr
# Out:
#                          Healthy life expectancy  Happiness_score
# Healthy life expectancy                 1.000000         0.756755
# Happiness_score                         0.756755         1.000000

# %% [markdown]
# A correlation heatmap that visualizes the correlation between Healthy Life Expectancy and Happiness Score

# %%
sns.heatmap(corr, annot = True, cmap = 'crest', fmt = ".2f")
# Out:
# <Axes: >

# %%
top_10 = df2.nlargest(10, "Happiness_score")

# %%
top_10
# Out:
#   Country name  Ladder score  upperwhisker  lowerwhisker  Log GDP per capita  \
# 0      Finland         7.741         7.815         7.667               1.844
# 1      Denmark         7.583         7.665         7.500               1.908
# 2      Iceland         7.525         7.618         7.433               1.881
# 3       Sweden         7.344         7.422         7.267               1.878
# 4       Israel         7.341         7.405         7.277               1.803
# 5  Netherlands         7.319         7.383         7.256               1.901
# 6       Norway         7.302         7.389         7.215               1.952
# 7   Luxembourg         7.122         7.213         7.031               2.141
# 8  Switzerland         7.060         7.147         6.973               1.970
# 9    Australia         7.057         7.141         6.973               1.854
#
#    Social support  Healthy life expectancy  Freedom to make life choices  \
# ...

# %%
last_10 = df2.nsmallest(10,"Happiness_score")

# %%
last_10
# Out:
#          Country name  Ladder score  upperwhisker  lowerwhisker  \
# 141           Lebanon         2.707         2.797         2.616
# 140           Lesotho         3.186         3.469         2.904
# 139      Sierra Leone         3.245         3.366         3.124
# 138  Congo (Kinshasa)         3.295         3.462         3.128
# 137          Zimbabwe         3.341         3.457         3.226
# 136          Botswana         3.383         3.558         3.209
# 135            Malawi         3.421         3.561         3.281
# 134          Eswatini         3.502         3.673         3.331
# 133            Zambia         3.502         3.636         3.368
# 132             Yemen         3.561         3.714         3.408
#
#      Log GDP per capita  Social support  Healthy life expectancy  \
# 141               1.377           0.577                    0.556
# 140               0.771           0.851                    0.000
# ...

# %%
df_sorted = df2.sort_values(by='Happiness_score', ascending=False)

# %%
df2
# Out:
#          Country name  Ladder score  upperwhisker  lowerwhisker  \
# 0             Finland         7.741         7.815         7.667
# 1             Denmark         7.583         7.665         7.500
# 2             Iceland         7.525         7.618         7.433
# 3              Sweden         7.344         7.422         7.267
# 4              Israel         7.341         7.405         7.277
# ..                ...           ...           ...           ...
# 137          Zimbabwe         3.341         3.457         3.226
# 138  Congo (Kinshasa)         3.295         3.462         3.128
# 139      Sierra Leone         3.245         3.366         3.124
# 140           Lesotho         3.186         3.469         2.904
# 141           Lebanon         2.707         2.797         2.616
#
#      Log GDP per capita  Social support  Healthy life expectancy  \
# 0                 1.844           1.572                    0.695
# ...

# %% [markdown]
# A horizontal bar chart representing the Top 10 Happiest Countries based on their Happiness Scores.

# %%
top_10_countries = df2.head(10)

plt.figure(figsize=(10, 5))
sns.barplot(x='Happiness_score', y='Country name', data=top_10_countries, hue='Country name', palette='Blues_r', legend=False)

# Customize plot
plt.title("Top 10 Happiest Countries", fontsize=14)
plt.xlabel("Happiness Score")
plt.ylabel("Country")
plt.xlim(0, top_10_countries['Happiness_score'].max() + 0.5)

plt.show()

# %% [markdown]
# A horizontal bar chart representing the Happiness Scores of the bottom 10 countries

# %%
last_countries_10 = df2.tail(10)

plt.figure(figsize=(10, 5))
sns.barplot(x='Happiness_score', y='Country name', data=last_countries_10, hue='Country name', palette='Reds', legend=False)

plt.title("Top 10 Happiest Countries", fontsize=14)
plt.xlabel("Happiness Score")
plt.ylabel("Country")
plt.xlim(0, top_10_countries['Happiness_score'].max() + 0.5)

plt.show()

# %%
df2.tail(10)
# Out:
#          Country name  Ladder score  upperwhisker  lowerwhisker  \
# 132             Yemen         3.561         3.714         3.408
# 133            Zambia         3.502         3.636         3.368
# 134          Eswatini         3.502         3.673         3.331
# 135            Malawi         3.421         3.561         3.281
# 136          Botswana         3.383         3.558         3.209
# 137          Zimbabwe         3.341         3.457         3.226
# 138  Congo (Kinshasa)         3.295         3.462         3.128
# 139      Sierra Leone         3.245         3.366         3.124
# 140           Lesotho         3.186         3.469         2.904
# 141           Lebanon         2.707         2.797         2.616
#
#      Log GDP per capita  Social support  Healthy life expectancy  \
# 132               0.671           1.281                    0.293
# 133               0.899           0.809                    0.264
# ...

# %% [markdown]
# This scatter plot helps us understand the relationship between a country's economic wealth (Log GDP per capita) and happiness levels (Happiness Score).

# %%
plt.figure(figsize=(10, 6))

sns.scatterplot(data=df2, x='Log GDP per capita', y='Happiness_score', hue='Country name', alpha=0.7, palette="viridis")

plt.title("Log GDP per Capita vs. Happiness Score", fontsize=14)
plt.xlabel("Log GDP per Capita")
plt.ylabel("Happiness Score")
plt.legend([],[], frameon=False)

plt.show()

# %% [markdown]
# This regression plot helps us analyze the relationship between Social Support and Happiness Score for different countries.

# %%
plt.figure(figsize=(10, 6))

sns.regplot(data=df2, x='Social support', y='Happiness_score', scatter_kws={"alpha": 0.5}, line_kws={"color": "red"})

plt.title("Social Support vs. Happiness Score", fontsize=14)
plt.xlabel("Social Support")
plt.ylabel("Happiness Score")

plt.show()

# %% [markdown]
# This is a bar plot comparing the Social Support and Happiness Score for the top 10 countries

# %%
top_10_countries = df2.nlargest(10, 'Social support')

plt.figure(figsize=(12, 6))


bar_width = 0.4


positions = range(len(top_10_countries))


plt.bar(positions, top_10_countries['Social support'], width=bar_width, label="Social Support", color='royalblue')

plt.bar([p + bar_width for p in positions], top_10_countries['Happiness_score'], width=bar_width, label="Happiness Score", color='lightcoral')

plt.xticks([p + bar_width/2 for p in positions], top_10_countries['Country name'], rotation=45, ha='right')
plt.title("Top 10 Countries: Social Support vs Happiness Score", fontsize=14)
plt.xlabel("Country")
plt.ylabel("Score")
plt.legend()


plt.show()

# %% [markdown]
# This bar plot compares Log GDP per Capita and Happiness Score for the top 10 countries

# %%
top_10_countries = df2.nlargest(10, 'Log GDP per capita')

plt.figure(figsize=(12, 6))

bar_width = 0.4

positions = range(len(top_10_countries))

plt.bar(positions, top_10_countries['Log GDP per capita'], width=bar_width, label="Log GDP per Capita", color='seagreen')

plt.bar([p + bar_width for p in positions], top_10_countries['Happiness_score'], width=bar_width, label="Happiness Score", color='goldenrod')

plt.xticks([p + bar_width/2 for p in positions], top_10_countries['Country name'], rotation=45, ha='right')
plt.title("Top 10 Countries: GDP per Capita vs Happiness Score", fontsize=14)
plt.xlabel("Country")
plt.ylabel("Score")
plt.legend()

plt.show()

# %% [markdown]
# **CONCLUSION**
# * The analysis of the World Happiness Report provided valuable insights into the factors influencing happiness across different countries.
